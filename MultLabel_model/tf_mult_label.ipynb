# %%
import tensorflow as tf

print('tensorflow version = ', tf.__version__)
# Out:
# tensorflow version =  2.10.1

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
# Define relevant variables for the ML task
image_size = (64, 64)
input_shape = (64, 64, 3)
batch_size = 8
num_classes = 4
learning_rate = 0.0006
num_epochs = 100

# %%
import tensorflow as tf
import os
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

# 字典對應表
dict_for_label = {
    'boat': [1, 0, 0, 0], 'dolphin': [0, 1, 0, 0], 'fish': [0, 0, 1, 0], 'whale': [0, 0, 0, 1],
    'boat+fish': [1, 0, 1, 0], 'boat+whale': [1, 0, 0, 1],
    'dolphin+boat': [1, 1, 0, 0], 'dolphin+whale': [0, 1, 0, 1], 'dolphin+fish': [0, 1, 1, 0],
    'fish+whale': [0, 0, 1, 1]
}

# 自訂多標籤資料集
class MultiLabelImageDataset(tf.keras.utils.Sequence):
    def __init__(self, image_folder, label_mapping, target_size=(224, 224), batch_size=32):
        """
        初始化資料集
        :param image_folder: 圖片資料夾的路徑
        :param label_mapping: 標籤字典
        :param target_size: 圖片調整大小
        :param batch_size: 每批的大小
        """
        self.image_folder = image_folder
        self.label_mapping = label_mapping
        self.target_size = target_size
        self.batch_size = batch_size

        # 掃描資料夾內的所有圖片
        self.image_paths = []
        self.labels = []
        for class_name, one_hot in label_mapping.items():
            class_folder = os.path.join(image_folder, class_name) # find specific folder
            if os.path.exists(class_folder):
                for file_name in os.listdir(class_folder):
                    if file_name.endswith(('.png', '.jpg', '.jpeg')):
                        self.image_paths.append(os.path.join(class_folder, file_name))
                        self.labels.append(one_hot)

        # 將資料轉換為 numpy 陣列
        self.image_paths = np.array(self.image_paths)
        self.labels = np.array(self.labels, dtype=np.float32)

    def __len__(self):
        """定義每個 epoch 包含的批次數"""
        return len(self.image_paths) // self.batch_size # self.batch_size

    def __getitem__(self, idx):
        """獲取一批資料"""
        # list slicing
        batch_images = self.image_paths[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_labels = self.labels[idx * self.batch_size:(idx + 1) * self.batch_size]

        images = []
        for image_path in batch_images:
            # 加載圖片並調整大小
            img = load_img(image_path, target_size=self.target_size)
            img_array = img_to_array(img) / 255.0  # 標準化到 [0, 1]
            images.append(img_array)

        return np.array(images), np.array(batch_labels)

# %%
# 使用自定義的多標籤資料集
source_folder = "dataset_v6/train"
test_folder = "dataset_v6/test"

def load_dataset(image_folder, label_mapping, target_size, batch_size):
    # 創建資料集實例
    dataset = MultiLabelImageDataset(
        image_folder=image_folder,
        label_mapping=dict_for_label,
        target_size=image_size,
        batch_size=batch_size
    )

    # 將資料集轉換為 TensorFlow Dataset 格式
    def generator():
        for i in range(len(dataset)):
            images, labels = dataset[i]  # 確保 dataset[i] 返回的是單張圖片和對應標籤
            for j in range(len(images)):
                yield images[j], labels[j]

    # TensorFlow Dataset API
    tf_dataset = tf.data.Dataset.from_generator(
        generator,
        output_types=(tf.float32, tf.float32),
        output_shapes=(
            (image_size[0], image_size[1], 3),  # Image shape: (height, width, channels)
            (len(dict_for_label["boat"]),)       # Label shape: (num_classes,)
        )
    )

    # 打亂資料集並分批次
    tf_dataset = tf_dataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(1)
    return tf_dataset

train_dataset = load_dataset(source_folder, dict_for_label, image_size, batch_size)
test_dataset = load_dataset(test_folder, dict_for_label, image_size, batch_size)

# 測試加載資料
for images, labels in train_dataset.take(1):  # 取第一個批次
    print("Images shape:", images.shape)  # (batch_size, height, width, channels)
    print("Labels shape:", labels.shape)  # (batch_size, num_classes)
    print("First label:", labels[0].numpy())  # 查看第一張圖片的標籤
    break
# Out:
# Images shape: (8, 64, 64, 3)
# Labels shape: (8, 4)
# First label: [0. 1. 0. 0.]

# %% [markdown]
# Create model

# %%
# import tensorflow as tf
# from tensorflow.keras import layers, models

# class CNN_Model(models.Model):
#     def __init__(self):
#         super(CNN_Model, self).__init__()
#         self.layer1 = self.conv_module_for_5x5(3, 8, 3, 1) 
#         self.layer2 = self.conv_twice(8, 14, 3, 1) 
#         self.layer3 = self.conv_twice(14, 44, 3, 1) 
#         self.layer4 = self.conv_twice(44, 20, 3, 1) 
#         self.layer5 = self.conv_twice_for_5x5(20, 8, 3, 1) 
#         self.fc1 = layers.Dense(4)

#     def call(self, x):
#         out = self.layer1(x)
#         out = self.layer2(out)
#         out = self.layer3(out)
#         out = self.layer4(out)
#         out = self.layer5(out)
#         out = tf.reshape(out, (tf.shape(out)[0], -1))
#         out = self.fc1(out)
#         return out

#     def conv_module(self, in_channels, out_channels, kernel_size, stride, padding=0):
#         return models.Sequential([
#             layers.Conv2D(out_channels, kernel_size, strides=stride, padding='same' if padding > 0 else 'valid', input_shape=(None, None, in_channels)),
#             layers.ReLU(),
#             layers.BatchNormalization(),
#             layers.MaxPool2D(pool_size=(2, 2))
#         ])

#     def conv_module_for_5x5(self, in_channels, out_channels, kernel_size, stride, padding=0):
#         return models.Sequential([
#             layers.Conv2D(out_channels, kernel_size, strides=stride, padding='same' if padding > 0 else 'valid', input_shape=(None, None, in_channels)),
#             layers.ReLU(),
#             layers.ZeroPadding2D(padding=1),
#             layers.Conv2D(out_channels, kernel_size, strides=stride, padding='same' if padding > 0 else 'valid'),
#             layers.ReLU(),
#             layers.BatchNormalization(),
#             layers.MaxPool2D(pool_size=(2, 2))
#         ])

#     def conv_twice(self, in_channels, out_channels, kernel_size, stride, padding=0):
#         return models.Sequential([
#             layers.Conv2D(out_channels, kernel_size=1, strides=stride, padding='same' if padding > 0 else 'valid', input_shape=(None, None, in_channels)),
#             layers.ReLU(),
#             layers.ZeroPadding2D(padding=1),
#             layers.Conv2D(out_channels, kernel_size, strides=stride, padding='same' if padding > 0 else 'valid'),
#             layers.ReLU(),
#             layers.BatchNormalization(),
#             layers.MaxPool2D(pool_size=(2, 2))
#         ])

#     def conv_twice_for_5x5(self, in_channels, out_channels, kernel_size, stride, padding=0):
#         return models.Sequential([
#             layers.Conv2D(out_channels, kernel_size=1, strides=stride, padding='same' if padding > 0 else 'valid', input_shape=(None, None, in_channels)),
#             layers.ReLU(),
#             layers.Conv2D(out_channels, kernel_size, strides=stride, padding='same' if padding > 0 else 'valid'),
#             layers.ReLU(),
#             layers.Conv2D(out_channels, kernel_size, strides=stride, padding='same' if padding > 0 else 'valid'),
#             layers.ReLU(),
#             layers.BatchNormalization(),
#             layers.MaxPool2D(pool_size=(2, 2))
#         ])

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.regularizers import L2

# 使用 Sequential 定義模型
model = models.Sequential()

# Layer 1
model.add(layers.Conv2D(8, kernel_size=(3, 3), strides=(1, 1), padding='valid', activation='relu', kernel_regularizer=L2(0.01), input_shape=(64, 64, 3)))
model.add(layers.Conv2D(8, kernel_size=(3, 3), strides=(1, 1), padding='valid', activation='relu', kernel_regularizer=L2(0.01)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# Layer 2
model.add(layers.Conv2D(16, kernel_size=(3, 3), strides=(1, 1), padding='valid', activation='relu', kernel_regularizer=L2(0.01)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# # Layer 3
# model.add(layers.Conv2D(32, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
# model.add(layers.BatchNormalization())
# model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# Layer 4
model.add(layers.Conv2D(32, kernel_size=(3, 3), strides=(1, 1), padding='valid', activation='relu', kernel_regularizer=L2(0.01)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# Layer 5
model.add(layers.Conv2D(16, kernel_size=(3, 3), strides=(1, 1), padding='valid', activation='relu', kernel_regularizer=L2(0.01)))
model.add(layers.Conv2D(16, kernel_size=(3, 3), strides=(1, 1), padding='valid', activation='relu', kernel_regularizer=L2(0.01)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# Flatten Layer
model.add(layers.Flatten())

# Fully Connected Layer
model.add(layers.Dense(4, kernel_regularizer=L2(0.01)))

# 檢查模型結構
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 62, 62, 8)         224
#
#  conv2d_41 (Conv2D)          (None, 60, 60, 8)         584
#
#  batch_normalization_38 (Bat  (None, 60, 60, 8)        32
#  chNormalization)
#
#  max_pooling2d_38 (MaxPoolin  (None, 30, 30, 8)        0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 28, 28, 16)        1168
#
#  batch_normalization_39 (Bat  (None, 28, 28, 16)       64
#  chNormalization)
#
#  max_pooling2d_39 (MaxPoolin  (None, 14, 14, 16)       0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 12, 12, 32)        4640
#
#  batch_normalization_40 (Bat  (None, 12, 12, 32)       128
#  chNormalization)
#
#  max_pooling2d_40 (MaxPoolin  (None, 6, 6, 32)         0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 4, 4, 16)          4624
#
#  conv2d_45 (Conv2D)          (None, 2, 2, 16)          2320
#
#  batch_normalization_41 (Bat  (None, 2, 2, 16)         64
#  chNormalization)
#
#  max_pooling2d_41 (MaxPoolin  (None, 1, 1, 16)         0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 16)                0
#
#  dense_8 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 13,916
# Trainable params: 13,772
# Non-trainable params: 144
# _________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint
import random

seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)

# 優化器與損失函數
optimizer = Adam(learning_rate=learning_rate)
lossFunc = BinaryCrossentropy(from_logits=True)

# 編譯模型
model.compile(optimizer=optimizer, 
              loss=lossFunc, 
              metrics=['binary_accuracy'])

# 儲存模型的檔名
modelSaveName = "TFModel_v3.h5"

# 設置檢查點回調，儲存最佳模型權重
checkpoint = ModelCheckpoint(filepath=modelSaveName, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_binary_accuracy', 
                             mode='max', 
                             verbose=1)

# early_stop
callback = tf.keras.callbacks.EarlyStopping(
    monitor='loss', min_delta=0, 
    patience=30, verbose=0, mode='min',
    restore_best_weights=True
)

# 開始訓練
history = model.fit(train_dataset,  # 訓練資料集
                    epochs=num_epochs,
                    validation_data=test_dataset,  # 驗證資料集 
                    callbacks=[checkpoint])  # 添加檢查點回調
# Out:
# Epoch 1/100
#      26/Unknown - 3s 28ms/step - loss: 1.5689 - binary_accuracy: 0.6851
# Epoch 1: val_binary_accuracy improved from -inf to 0.62689, saving model to TFModel_v3.h5
# 27/27 [==============================] - 4s 74ms/step - loss: 1.5612 - binary_accuracy: 0.6875 - val_loss: 1.5327 - val_binary_accuracy: 0.6269
# Epoch 2/100
# 27/27 [==============================] - ETA: 0s - loss: 1.3668 - binary_accuracy: 0.7766
# Epoch 2: val_binary_accuracy did not improve from 0.62689
# 27/27 [==============================] - 2s 57ms/step - loss: 1.3668 - binary_accuracy: 0.7766 - val_loss: 1.5035 - val_binary_accuracy: 0.6269
# Epoch 3/100
# 26/27 [===========================>..] - ETA: 0s - loss: 1.2947 - binary_accuracy: 0.7981
# Epoch 3: val_binary_accuracy did not improve from 0.62689
# 27/27 [==============================] - 2s 55ms/step - loss: 1.2961 - binary_accuracy: 0.7963 - val_loss: 1.4787 - val_binary_accuracy: 0.6269
# Epoch 4/100
# 26/27 [===========================>..] - ETA: 0s - loss: 1.2046 - binary_accuracy: 0.8474
# Epoch 4: val_binary_accuracy did not improve from 0.62689
# 27/27 [==============================] - 2s 65ms/step - loss: 1.1996 - binary_accuracy: 0.8507 - val_loss: 1.4597 - val_binary_accuracy: 0.6269
# Epoch 5/100
# 26/27 [===========================>..] - ETA: 0s - loss: 1.1647 - binary_accuracy: 0.8293
# Epoch 5: val_binary_accuracy did not improve from 0.62689
# 27/27 [==============================] - 2s 57ms/step - loss: 1.1619 - binary_accuracy: 0.8333 - val_loss: 1.4385 - val_binary_accuracy: 0.6269
# Epoch 6/100
# 26/27 [===========================>..] - ETA: 0s - loss: 1.1039 - binary_accuracy: 0.8546
# Epoch 6: val_binary_accuracy did not improve from 0.62689
# 27/27 [==============================] - 2s 77ms/step - loss: 1.1041 - binary_accuracy: 0.8542 - val_loss: 1.4150 - val_binary_accuracy: 0.6269
# Epoch 7/100
# 26/27 [===========================>..] - ETA: 0s - loss: 1.0417 - binary_accuracy: 0.8786
# Epoch 7: val_binary_accuracy did not improve from 0.62689
# 27/27 [==============================] - 2s 58ms/step - loss: 1.0389 - binary_accuracy: 0.8808 - val_loss: 1.3970 - val_binary_accuracy: 0.5900
# Epoch 8/100
# 26/27 [===========================>..] - ETA: 0s - loss: 1.0415 - binary_accuracy: 0.8510
# Epoch 8: val_binary_accuracy did not improve from 0.62689
# 27/27 [==============================] - 2s 54ms/step - loss: 1.0430 - binary_accuracy: 0.8461 - val_loss: 1.3773 - val_binary_accuracy: 0.5502
# Epoch 9/100
# 27/27 [==============================] - ETA: 0s - loss: 1.0140 - binary_accuracy: 0.8646
# Epoch 9: val_binary_accuracy did not improve from 0.62689
# 27/27 [==============================] - 2s 56ms/step - loss: 1.0140 - binary_accuracy: 0.8646 - val_loss: 1.3597 - val_binary_accuracy: 0.6146
# Epoch 10/100
# 27/27 [==============================] - ETA: 0s - loss: 0.9589 - binary_accuracy: 0.8785
# Epoch 10: val_binary_accuracy improved from 0.62689 to 0.65246, saving model to TFModel_v3.h5
# 27/27 [==============================] - 2s 65ms/step - loss: 0.9589 - binary_accuracy: 0.8785 - val_loss: 1.3425 - val_binary_accuracy: 0.6525
# Epoch 11/100
# 27/27 [==============================] - ETA: 0s - loss: 0.9303 - binary_accuracy: 0.8900
# Epoch 11: val_binary_accuracy did not improve from 0.65246
# 27/27 [==============================] - 2s 56ms/step - loss: 0.9303 - binary_accuracy: 0.8900 - val_loss: 1.3166 - val_binary_accuracy: 0.6108
# Epoch 12/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.8925 - binary_accuracy: 0.8918
# Epoch 12: val_binary_accuracy did not improve from 0.65246
# 27/27 [==============================] - 2s 62ms/step - loss: 0.8926 - binary_accuracy: 0.8900 - val_loss: 1.2901 - val_binary_accuracy: 0.6222
# Epoch 13/100
# 27/27 [==============================] - ETA: 0s - loss: 0.8523 - binary_accuracy: 0.9016
# Epoch 13: val_binary_accuracy improved from 0.65246 to 0.68277, saving model to TFModel_v3.h5
# 27/27 [==============================] - 2s 59ms/step - loss: 0.8523 - binary_accuracy: 0.9016 - val_loss: 1.2566 - val_binary_accuracy: 0.6828
# Epoch 14/100
# 27/27 [==============================] - ETA: 0s - loss: 0.8147 - binary_accuracy: 0.9190
# Epoch 14: val_binary_accuracy did not improve from 0.68277
# 27/27 [==============================] - 2s 58ms/step - loss: 0.8147 - binary_accuracy: 0.9190 - val_loss: 1.2277 - val_binary_accuracy: 0.6809
# Epoch 15/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7958 - binary_accuracy: 0.9236
# Epoch 15: val_binary_accuracy did not improve from 0.68277
# 27/27 [==============================] - 2s 76ms/step - loss: 0.7958 - binary_accuracy: 0.9236 - val_loss: 1.1888 - val_binary_accuracy: 0.6723
# Epoch 16/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7681 - binary_accuracy: 0.9248
# Epoch 16: val_binary_accuracy improved from 0.68277 to 0.71023, saving model to TFModel_v3.h5
# 27/27 [==============================] - 2s 60ms/step - loss: 0.7681 - binary_accuracy: 0.9248 - val_loss: 1.1491 - val_binary_accuracy: 0.7102
# Epoch 17/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7593 - binary_accuracy: 0.9190
# Epoch 17: val_binary_accuracy improved from 0.71023 to 0.71970, saving model to TFModel_v3.h5
# 27/27 [==============================] - 2s 64ms/step - loss: 0.7593 - binary_accuracy: 0.9190 - val_loss: 1.1133 - val_binary_accuracy: 0.7197
# Epoch 18/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7496 - binary_accuracy: 0.9225
# Epoch 18: val_binary_accuracy improved from 0.71970 to 0.74811, saving model to TFModel_v3.h5
# 27/27 [==============================] - 2s 59ms/step - loss: 0.7496 - binary_accuracy: 0.9225 - val_loss: 1.0650 - val_binary_accuracy: 0.7481
# Epoch 19/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.7142 - binary_accuracy: 0.9399
# Epoch 19: val_binary_accuracy improved from 0.74811 to 0.76326, saving model to TFModel_v3.h5
# 27/27 [==============================] - 2s 71ms/step - loss: 0.7139 - binary_accuracy: 0.9387 - val_loss: 1.0501 - val_binary_accuracy: 0.7633
# Epoch 20/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.7075 - binary_accuracy: 0.9255
# Epoch 20: val_binary_accuracy did not improve from 0.76326
# 27/27 [==============================] - 2s 69ms/step - loss: 0.7092 - binary_accuracy: 0.9248 - val_loss: 0.9906 - val_binary_accuracy: 0.7481
# Epoch 21/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.6608 - binary_accuracy: 0.9507
# Epoch 21: val_binary_accuracy did not improve from 0.76326
# 27/27 [==============================] - 2s 55ms/step - loss: 0.6590 - binary_accuracy: 0.9525 - val_loss: 1.0109 - val_binary_accuracy: 0.7566
# Epoch 22/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.6483 - binary_accuracy: 0.9555
# Epoch 22: val_binary_accuracy improved from 0.76326 to 0.78693, saving model to TFModel_v3.h5
# 27/27 [==============================] - 2s 78ms/step - loss: 0.6522 - binary_accuracy: 0.9525 - val_loss: 0.9613 - val_binary_accuracy: 0.7869
# Epoch 23/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.6254 - binary_accuracy: 0.9550
# Epoch 23: val_binary_accuracy did not improve from 0.78693
# 27/27 [==============================] - 2s 64ms/step - loss: 0.6253 - binary_accuracy: 0.9560 - val_loss: 0.9698 - val_binary_accuracy: 0.7661
# Epoch 24/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.5964 - binary_accuracy: 0.9748
# Epoch 24: val_binary_accuracy did not improve from 0.78693
# 27/27 [==============================] - 2s 65ms/step - loss: 0.5990 - binary_accuracy: 0.9722 - val_loss: 1.0069 - val_binary_accuracy: 0.7443
# Epoch 25/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5748 - binary_accuracy: 0.9688
# Epoch 25: val_binary_accuracy did not improve from 0.78693
# 27/27 [==============================] - 2s 60ms/step - loss: 0.5748 - binary_accuracy: 0.9688 - val_loss: 0.9977 - val_binary_accuracy: 0.7225
# Epoch 26/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5806 - binary_accuracy: 0.9676
# Epoch 26: val_binary_accuracy did not improve from 0.78693
# 27/27 [==============================] - 2s 55ms/step - loss: 0.5806 - binary_accuracy: 0.9676 - val_loss: 0.9190 - val_binary_accuracy: 0.7670
# Epoch 27/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.5530 - binary_accuracy: 0.9736
# Epoch 27: val_binary_accuracy did not improve from 0.78693
# 27/27 [==============================] - 2s 55ms/step - loss: 0.5508 - binary_accuracy: 0.9745 - val_loss: 0.9041 - val_binary_accuracy: 0.7822
# Epoch 28/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5373 - binary_accuracy: 0.9757
# Epoch 28: val_binary_accuracy improved from 0.78693 to 0.81439, saving model to TFModel_v3.h5
# 27/27 [==============================] - 2s 57ms/step - loss: 0.5373 - binary_accuracy: 0.9757 - val_loss: 0.8473 - val_binary_accuracy: 0.8144
# Epoch 29/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.5334 - binary_accuracy: 0.9784
# Epoch 29: val_binary_accuracy did not improve from 0.81439
# 27/27 [==============================] - 2s 59ms/step - loss: 0.5320 - binary_accuracy: 0.9792 - val_loss: 0.9848 - val_binary_accuracy: 0.7169
# Epoch 30/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.5158 - binary_accuracy: 0.9784
# Epoch 30: val_binary_accuracy improved from 0.81439 to 0.83807, saving model to TFModel_v3.h5
# 27/27 [==============================] - 2s 72ms/step - loss: 0.5150 - binary_accuracy: 0.9792 - val_loss: 0.8614 - val_binary_accuracy: 0.8381
# Epoch 31/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.5217 - binary_accuracy: 0.9775
# Epoch 31: val_binary_accuracy did not improve from 0.83807
# 27/27 [==============================] - 2s 60ms/step - loss: 0.5205 - binary_accuracy: 0.9769 - val_loss: 0.8933 - val_binary_accuracy: 0.7964
# Epoch 32/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5145 - binary_accuracy: 0.9780
# Epoch 32: val_binary_accuracy did not improve from 0.83807
# 27/27 [==============================] - 2s 57ms/step - loss: 0.5145 - binary_accuracy: 0.9780 - val_loss: 0.8816 - val_binary_accuracy: 0.8021
# Epoch 33/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.4933 - binary_accuracy: 0.9844
# Epoch 33: val_binary_accuracy did not improve from 0.83807
# 27/27 [==============================] - 2s 57ms/step - loss: 0.4923 - binary_accuracy: 0.9850 - val_loss: 0.8337 - val_binary_accuracy: 0.8191
# Epoch 34/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4943 - binary_accuracy: 0.9803
# Epoch 34: val_binary_accuracy did not improve from 0.83807
# 27/27 [==============================] - 2s 76ms/step - loss: 0.4943 - binary_accuracy: 0.9803 - val_loss: 0.8399 - val_binary_accuracy: 0.8116
# Epoch 35/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.4718 - binary_accuracy: 0.9844
# Epoch 35: val_binary_accuracy did not improve from 0.83807
# 27/27 [==============================] - 2s 54ms/step - loss: 0.4711 - binary_accuracy: 0.9850 - val_loss: 0.8777 - val_binary_accuracy: 0.7879
# Epoch 36/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4453 - binary_accuracy: 0.9954
# Epoch 36: val_binary_accuracy did not improve from 0.83807
# 27/27 [==============================] - 2s 55ms/step - loss: 0.4453 - binary_accuracy: 0.9954 - val_loss: 0.8405 - val_binary_accuracy: 0.7964
# Epoch 37/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.4443 - binary_accuracy: 0.9892
# Epoch 37: val_binary_accuracy did not improve from 0.83807
# 27/27 [==============================] - 2s 77ms/step - loss: 0.4438 - binary_accuracy: 0.9896 - val_loss: 0.8184 - val_binary_accuracy: 0.7992
# Epoch 38/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4394 - binary_accuracy: 0.9861
# Epoch 38: val_binary_accuracy improved from 0.83807 to 0.84280, saving model to TFModel_v3.h5
# 27/27 [==============================] - 3s 77ms/step - loss: 0.4394 - binary_accuracy: 0.9861 - val_loss: 0.7792 - val_binary_accuracy: 0.8428
# Epoch 39/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4297 - binary_accuracy: 0.9850
# Epoch 39: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 62ms/step - loss: 0.4297 - binary_accuracy: 0.9850 - val_loss: 0.7613 - val_binary_accuracy: 0.8352
# Epoch 40/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.4414 - binary_accuracy: 0.9796
# Epoch 40: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 71ms/step - loss: 0.4427 - binary_accuracy: 0.9780 - val_loss: 0.9224 - val_binary_accuracy: 0.8002
# Epoch 41/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4315 - binary_accuracy: 0.9861
# Epoch 41: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 62ms/step - loss: 0.4315 - binary_accuracy: 0.9861 - val_loss: 0.7902 - val_binary_accuracy: 0.8229
# Epoch 42/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4090 - binary_accuracy: 0.9907
# Epoch 42: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 54ms/step - loss: 0.4090 - binary_accuracy: 0.9907 - val_loss: 0.7803 - val_binary_accuracy: 0.8324
# Epoch 43/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.4092 - binary_accuracy: 0.9844
# Epoch 43: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 58ms/step - loss: 0.4115 - binary_accuracy: 0.9826 - val_loss: 0.7940 - val_binary_accuracy: 0.8040
# Epoch 44/100
# 27/27 [==============================] - ETA: 0s - loss: 0.3927 - binary_accuracy: 0.9954
# Epoch 44: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 56ms/step - loss: 0.3927 - binary_accuracy: 0.9954 - val_loss: 0.7690 - val_binary_accuracy: 0.8314
# Epoch 45/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.3849 - binary_accuracy: 0.9940
# Epoch 45: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 54ms/step - loss: 0.3840 - binary_accuracy: 0.9942 - val_loss: 0.7292 - val_binary_accuracy: 0.8400
# Epoch 46/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.3787 - binary_accuracy: 0.9940
# Epoch 46: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 69ms/step - loss: 0.3781 - binary_accuracy: 0.9942 - val_loss: 0.7365 - val_binary_accuracy: 0.8182
# Epoch 47/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.3736 - binary_accuracy: 0.9928
# Epoch 47: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 62ms/step - loss: 0.3730 - binary_accuracy: 0.9931 - val_loss: 0.9113 - val_binary_accuracy: 0.7642
# Epoch 48/100
# 27/27 [==============================] - ETA: 0s - loss: 0.3897 - binary_accuracy: 0.9815
# Epoch 48: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 57ms/step - loss: 0.3897 - binary_accuracy: 0.9815 - val_loss: 0.7788 - val_binary_accuracy: 0.8182
# Epoch 49/100
# 27/27 [==============================] - ETA: 0s - loss: 0.3798 - binary_accuracy: 0.9896
# Epoch 49: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 79ms/step - loss: 0.3798 - binary_accuracy: 0.9896 - val_loss: 0.7909 - val_binary_accuracy: 0.8097
# Epoch 50/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.3614 - binary_accuracy: 0.9928
# Epoch 50: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 55ms/step - loss: 0.3615 - binary_accuracy: 0.9931 - val_loss: 0.7476 - val_binary_accuracy: 0.8352
# Epoch 51/100
# 27/27 [==============================] - ETA: 0s - loss: 0.3663 - binary_accuracy: 0.9907
# Epoch 51: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 58ms/step - loss: 0.3663 - binary_accuracy: 0.9907 - val_loss: 0.7556 - val_binary_accuracy: 0.8248
# Epoch 52/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.3690 - binary_accuracy: 0.9808
# Epoch 52: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 76ms/step - loss: 0.3681 - binary_accuracy: 0.9803 - val_loss: 0.8073 - val_binary_accuracy: 0.7775
# Epoch 53/100
# 27/27 [==============================] - ETA: 0s - loss: 0.3505 - binary_accuracy: 0.9931
# Epoch 53: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 63ms/step - loss: 0.3505 - binary_accuracy: 0.9931 - val_loss: 0.7645 - val_binary_accuracy: 0.7936
# Epoch 54/100
# 27/27 [==============================] - ETA: 0s - loss: 0.3392 - binary_accuracy: 0.9988
# Epoch 54: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 71ms/step - loss: 0.3392 - binary_accuracy: 0.9988 - val_loss: 0.7341 - val_binary_accuracy: 0.8201
# Epoch 55/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.3240 - binary_accuracy: 1.0000
# Epoch 55: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 60ms/step - loss: 0.3241 - binary_accuracy: 1.0000 - val_loss: 0.7146 - val_binary_accuracy: 0.8220
# Epoch 56/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.3139 - binary_accuracy: 1.0000
# Epoch 56: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 64ms/step - loss: 0.3143 - binary_accuracy: 1.0000 - val_loss: 0.6855 - val_binary_accuracy: 0.8381
# Epoch 57/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.3145 - binary_accuracy: 0.9940
# Epoch 57: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 57ms/step - loss: 0.3144 - binary_accuracy: 0.9942 - val_loss: 0.8003 - val_binary_accuracy: 0.7907
# Epoch 58/100
# 27/27 [==============================] - ETA: 0s - loss: 0.3114 - binary_accuracy: 0.9954
# Epoch 58: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 65ms/step - loss: 0.3114 - binary_accuracy: 0.9954 - val_loss: 0.6947 - val_binary_accuracy: 0.8314
# Epoch 59/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.3042 - binary_accuracy: 0.9988
# Epoch 59: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 54ms/step - loss: 0.3040 - binary_accuracy: 0.9988 - val_loss: 0.6786 - val_binary_accuracy: 0.8362
# Epoch 60/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.3014 - binary_accuracy: 0.9987
# Epoch 60: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 70ms/step - loss: 0.3021 - binary_accuracy: 0.9977 - val_loss: 0.7200 - val_binary_accuracy: 0.8229
# Epoch 61/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2958 - binary_accuracy: 0.9964
# Epoch 61: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 66ms/step - loss: 0.2956 - binary_accuracy: 0.9965 - val_loss: 0.7248 - val_binary_accuracy: 0.8182
# Epoch 62/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2914 - binary_accuracy: 0.9954
# Epoch 62: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 67ms/step - loss: 0.2914 - binary_accuracy: 0.9954 - val_loss: 0.6922 - val_binary_accuracy: 0.8116
# Epoch 63/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2825 - binary_accuracy: 0.9976
# Epoch 63: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 69ms/step - loss: 0.2828 - binary_accuracy: 0.9977 - val_loss: 0.6676 - val_binary_accuracy: 0.8381
# Epoch 64/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2765 - binary_accuracy: 0.9988
# Epoch 64: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 54ms/step - loss: 0.2765 - binary_accuracy: 0.9988 - val_loss: 0.7003 - val_binary_accuracy: 0.8258
# Epoch 65/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.2734 - binary_accuracy: 1.0000
# Epoch 65: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 55ms/step - loss: 0.2726 - binary_accuracy: 1.0000 - val_loss: 0.6655 - val_binary_accuracy: 0.8381
# Epoch 66/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2627 - binary_accuracy: 1.0000
# Epoch 66: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 65ms/step - loss: 0.2624 - binary_accuracy: 1.0000 - val_loss: 0.6571 - val_binary_accuracy: 0.8362
# Epoch 67/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2625 - binary_accuracy: 0.9977
# Epoch 67: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 69ms/step - loss: 0.2625 - binary_accuracy: 0.9977 - val_loss: 0.7353 - val_binary_accuracy: 0.8116
# Epoch 68/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2641 - binary_accuracy: 0.9965
# Epoch 68: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 55ms/step - loss: 0.2641 - binary_accuracy: 0.9965 - val_loss: 0.7422 - val_binary_accuracy: 0.8021
# Epoch 69/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2598 - binary_accuracy: 0.9988
# Epoch 69: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 58ms/step - loss: 0.2598 - binary_accuracy: 0.9988 - val_loss: 0.6867 - val_binary_accuracy: 0.8362
# Epoch 70/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2581 - binary_accuracy: 0.9964
# Epoch 70: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 55ms/step - loss: 0.2623 - binary_accuracy: 0.9954 - val_loss: 0.6689 - val_binary_accuracy: 0.8258
# Epoch 71/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2558 - binary_accuracy: 0.9965
# Epoch 71: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 58ms/step - loss: 0.2558 - binary_accuracy: 0.9965 - val_loss: 0.6692 - val_binary_accuracy: 0.8201
# Epoch 72/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2544 - binary_accuracy: 0.9964
# Epoch 72: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 68ms/step - loss: 0.2544 - binary_accuracy: 0.9954 - val_loss: 0.6632 - val_binary_accuracy: 0.8248
# Epoch 73/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2517 - binary_accuracy: 0.9942
# Epoch 73: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 3s 76ms/step - loss: 0.2517 - binary_accuracy: 0.9942 - val_loss: 0.7051 - val_binary_accuracy: 0.8144
# Epoch 74/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2704 - binary_accuracy: 0.9873
# Epoch 74: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 3s 76ms/step - loss: 0.2704 - binary_accuracy: 0.9873 - val_loss: 0.6133 - val_binary_accuracy: 0.8267
# Epoch 75/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2564 - binary_accuracy: 0.9919
# Epoch 75: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 55ms/step - loss: 0.2564 - binary_accuracy: 0.9919 - val_loss: 0.7364 - val_binary_accuracy: 0.7756
# Epoch 76/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2584 - binary_accuracy: 0.9904
# Epoch 76: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 77ms/step - loss: 0.2580 - binary_accuracy: 0.9907 - val_loss: 0.8635 - val_binary_accuracy: 0.7386
# Epoch 77/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2594 - binary_accuracy: 0.9916
# Epoch 77: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 74ms/step - loss: 0.2593 - binary_accuracy: 0.9919 - val_loss: 0.7986 - val_binary_accuracy: 0.7775
# Epoch 78/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.2593 - binary_accuracy: 0.9912
# Epoch 78: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 54ms/step - loss: 0.2582 - binary_accuracy: 0.9919 - val_loss: 0.6299 - val_binary_accuracy: 0.8059
# Epoch 79/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2469 - binary_accuracy: 0.9940
# Epoch 79: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 60ms/step - loss: 0.2460 - binary_accuracy: 0.9942 - val_loss: 0.7990 - val_binary_accuracy: 0.7850
# Epoch 80/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2426 - binary_accuracy: 0.9942
# Epoch 80: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 55ms/step - loss: 0.2426 - binary_accuracy: 0.9942 - val_loss: 0.7136 - val_binary_accuracy: 0.8125
# Epoch 81/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2388 - binary_accuracy: 0.9954
# Epoch 81: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 69ms/step - loss: 0.2388 - binary_accuracy: 0.9954 - val_loss: 0.7174 - val_binary_accuracy: 0.8210
# Epoch 82/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2348 - binary_accuracy: 0.9940
# Epoch 82: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 55ms/step - loss: 0.2350 - binary_accuracy: 0.9942 - val_loss: 0.6117 - val_binary_accuracy: 0.8239
# Epoch 83/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2306 - binary_accuracy: 0.9931
# Epoch 83: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 54ms/step - loss: 0.2306 - binary_accuracy: 0.9931 - val_loss: 0.7094 - val_binary_accuracy: 0.8172
# Epoch 84/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2302 - binary_accuracy: 0.9954
# Epoch 84: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 55ms/step - loss: 0.2302 - binary_accuracy: 0.9954 - val_loss: 0.6716 - val_binary_accuracy: 0.8068
# Epoch 85/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2212 - binary_accuracy: 1.0000
# Epoch 85: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 64ms/step - loss: 0.2215 - binary_accuracy: 1.0000 - val_loss: 0.6483 - val_binary_accuracy: 0.8248
# Epoch 86/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.2130 - binary_accuracy: 1.0000
# Epoch 86: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 65ms/step - loss: 0.2133 - binary_accuracy: 1.0000 - val_loss: 0.5864 - val_binary_accuracy: 0.8314
# Epoch 87/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2198 - binary_accuracy: 0.9976
# Epoch 87: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 60ms/step - loss: 0.2203 - binary_accuracy: 0.9977 - val_loss: 0.6370 - val_binary_accuracy: 0.8229
# Epoch 88/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2123 - binary_accuracy: 0.9988
# Epoch 88: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 76ms/step - loss: 0.2123 - binary_accuracy: 0.9988 - val_loss: 0.6401 - val_binary_accuracy: 0.8333
# Epoch 89/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2056 - binary_accuracy: 0.9977
# Epoch 89: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 59ms/step - loss: 0.2056 - binary_accuracy: 0.9977 - val_loss: 0.6188 - val_binary_accuracy: 0.8258
# Epoch 90/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.2045 - binary_accuracy: 1.0000
# Epoch 90: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 54ms/step - loss: 0.2047 - binary_accuracy: 1.0000 - val_loss: 0.5927 - val_binary_accuracy: 0.8295
# Epoch 91/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2467 - binary_accuracy: 0.9850
# Epoch 91: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 56ms/step - loss: 0.2467 - binary_accuracy: 0.9850 - val_loss: 0.7850 - val_binary_accuracy: 0.7358
# Epoch 92/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2526 - binary_accuracy: 0.9780
# Epoch 92: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 58ms/step - loss: 0.2526 - binary_accuracy: 0.9780 - val_loss: 0.6444 - val_binary_accuracy: 0.8116
# Epoch 93/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2367 - binary_accuracy: 0.9861
# Epoch 93: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 70ms/step - loss: 0.2367 - binary_accuracy: 0.9861 - val_loss: 0.6175 - val_binary_accuracy: 0.8258
# Epoch 94/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2442 - binary_accuracy: 0.9784
# Epoch 94: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 63ms/step - loss: 0.2439 - binary_accuracy: 0.9780 - val_loss: 0.8571 - val_binary_accuracy: 0.7850
# Epoch 95/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2266 - binary_accuracy: 0.9884
# Epoch 95: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 61ms/step - loss: 0.2266 - binary_accuracy: 0.9884 - val_loss: 0.6801 - val_binary_accuracy: 0.8381
# Epoch 96/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2225 - binary_accuracy: 0.9965
# Epoch 96: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 70ms/step - loss: 0.2225 - binary_accuracy: 0.9965 - val_loss: 0.6981 - val_binary_accuracy: 0.7964
# Epoch 97/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2173 - binary_accuracy: 0.9928
# Epoch 97: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 62ms/step - loss: 0.2175 - binary_accuracy: 0.9931 - val_loss: 0.7011 - val_binary_accuracy: 0.7775
# Epoch 98/100
# 27/27 [==============================] - ETA: 0s - loss: 0.2108 - binary_accuracy: 0.9954
# Epoch 98: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 54ms/step - loss: 0.2108 - binary_accuracy: 0.9954 - val_loss: 0.5831 - val_binary_accuracy: 0.8400
# Epoch 99/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.1996 - binary_accuracy: 0.9988
# Epoch 99: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 59ms/step - loss: 0.1992 - binary_accuracy: 0.9988 - val_loss: 0.7090 - val_binary_accuracy: 0.7576
# Epoch 100/100
# 27/27 [==============================] - ETA: 0s - loss: 0.1934 - binary_accuracy: 0.9977
# Epoch 100: val_binary_accuracy did not improve from 0.84280
# 27/27 [==============================] - 2s 56ms/step - loss: 0.1934 - binary_accuracy: 0.9977 - val_loss: 0.6656 - val_binary_accuracy: 0.7708

# %%
import matplotlib.pyplot as plt

# 找到最佳驗證準確率及其對應的 Epoch
best_epoch = np.argmax(history.history['val_binary_accuracy']) + 1  # 因為 index 從 0 開始
best_val_acc = max(history.history['val_binary_accuracy'])

print(f"Best Epoch: {best_epoch}, Best Validation Accuracy: {best_val_acc:.4f}")

plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xlim([0, num_epochs])
plt.ylim([0, 1])
plt.legend(['Train', 'Test'], loc='lower right')
# 標註最終儲存的點
plt.scatter(best_epoch, best_val_acc, color='red')
plt.annotate(f'Epoch {best_epoch}\nAcc: {best_val_acc:.4f}', 
             (best_epoch, best_val_acc), 
             textcoords="offset points", xytext=(-35, 0), ha='center', color='green')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.xlim([0, num_epochs])
plt.ylim([0, 2])
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

model.load_weights(modelSaveName)   # load best weights
test_loss, test_acc = model.evaluate(test_dataset, verbose=1)
print('test accuracy = ', test_acc)
# Out:
# Best Epoch: 38, Best Validation Accuracy: 0.8428
# 33/33 [==============================] - 1s 9ms/step - loss: 0.7792 - binary_accuracy: 0.8428
# test accuracy =  0.8428030014038086

# %% [markdown]
# Save json file

# %%
# 儲存模型架構
model_json = model.to_json()
with open("tf_model_structure.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# 預測資料

# %% [markdown]
# load h5 to model

# %%
model.load_weights('TFModel_v3.h5', by_name=True)
test_input = tf.random.normal([1, 64, 64, 3])
output = model(test_input)
print("Model output:", output)
# Out:
# Model output: tf.Tensor([[ -9.995917  23.52737  -12.093923 -38.28831 ]], shape=(1, 4), dtype=float32)

# %% [markdown]
# Predict data like pytorch way

# %%
import numpy as np
from sklearn.metrics import accuracy_score
import tensorflow as tf

# 初始化預測數據
pred_list = []
label_list = []

# 預測模型
for images, labels in test_dataset:
    # 預測輸出 (模型的 output 是 (batch_size, num_classes))
    outputs = model(images, training=False)
    # print(outputs)
    
    # 計算每個類別的預測概率（Sigmoid 函數處理）
    predicted_prob = tf.sigmoid(outputs)
    # print(predicted_prob)
    
    # 將每個類別的預測概率與閾值 0.5 比較，大於 0.5 表示該類別存在 (標記為 1)
    predicted = tf.cast(outputs > 0.5, tf.int32)
    # print(predicted)

    # 將預測和真實標籤加入列表
    pred_list.extend(predicted.numpy())
    label_list.extend(labels.numpy())

# %%
# 改為 numpy 陣列，便於計算
pred_list = np.array(pred_list)
label_list = np.array(label_list)

# 計算整體準確度
accuracy = accuracy_score(label_list, pred_list)
print(f'Subset Accuracy of the network on the test images: {accuracy * 100:.2f} %')

# 自定義的準確度函數
def Accuracy(y_pred, y_true):
    count = 0
    for i in range(y_true.shape[0]):  # 幾個樣本
        p = np.sum(np.logical_and(y_pred[i], y_true[i]))
        q = np.sum(np.logical_or(y_pred[i], y_true[i]))
        count += p / q
    return count / y_true.shape[0]

print(f'Accuracy of the network on the test images: {Accuracy(pred_list, label_list) * 100:.2f} %')
# Out:
# Subset Accuracy of the network on the test images: 47.35 %
# Accuracy of the network on the test images: 69.44 %

# %%
# precision, recall, f1-score
from sklearn.metrics import precision_score, recall_score, f1_score

print(f'Precision: {precision_score(label_list, pred_list, average="samples")}')
print(f'Recall: {recall_score(label_list, pred_list, average="samples")}')
print(f'F1-score: {f1_score(label_list, pred_list, average="samples")}')
# Out:
# Precision: 0.9015151515151515
# Recall: 0.7083333333333334
# F1-score: 0.7695707070707071
# d:\ancode\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np

pred_list = np.array(pred_list)
label_list = np.array(label_list)

for i , class_name in enumerate(dict_for_label.keys()):
    if i >= num_classes:
        break

    cm = confusion_matrix(label_list[:, i], pred_list[:, i])
    
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix for {class_name}')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %%
from sklearn.metrics import hamming_loss

# 計算 Hamming Loss
hloss = hamming_loss(label_list, pred_list)
print(f"Hamming Loss: {hloss}")
# Out:
# Hamming Loss: 0.1571969696969697
